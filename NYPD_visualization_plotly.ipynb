# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.0)

# %%
import calendar
import datetime
import numpy as np
import pandas as pd

import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
df = pd.read_csv('/content/NYPD_Shooting.csv')
df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0     244608249  05/05/2022   00:10:00  MANHATTAN            INSIDE        14
# 1     247542571  07/04/2022   22:20:00      BRONX           OUTSIDE        48
# 2      84967535  05/27/2012   19:35:00     QUEENS               NaN       103
# 3     202853370  09/24/2019   21:00:00      BRONX               NaN        42
# 4      27078636  02/25/2007   21:00:00   BROOKLYN               NaN        83
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0         COMMERCIAL   VIDEO STORE
# 1                0.0             STREET        (null)
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG  ... PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0                     True  ...        M     BLACK         25-44       M
# 1                     True  ...   (null)    (null)         18-24       M
# 2                    False  ...      NaN       NaN         18-24       M
# 3                    False  ...        M   UNKNOWN         25-44       M
# 4                    False  ...        M     BLACK         25-44       M
#
#   VIC_RACE   X_COORD_CD     Y_COORD_CD   Latitude  Longitude  \
# 0    BLACK   986050.000  214231.000000  40.754692 -73.993500
# 1    BLACK  1016802.000  250581.000000  40.854402 -73.882330
# 2    BLACK  1048632.000  198262.000000  40.710634 -73.767773
# 3    BLACK  1014493.000  242565.000000  40.832417 -73.890714
# 4    BLACK  1009149.375  190104.703125  40.688443 -73.910219
#
#                                          Lon_Lat
# 0                     POINT (-73.9935 40.754692)
# 1                    POINT (-73.88233 40.854402)
# 2   POINT (-73.76777349199995 40.71063412500007)
# 3  POINT (-73.89071440599997 40.832416753000075)
# 4   POINT (-73.91021857399994 40.68844345900004)
#
# [5 rows x 21 columns]

# %%
df = df.drop(
    labels=['INCIDENT_KEY', 'JURISDICTION_CODE', 'PERP_RACE', 'Lon_Lat',
            'PERP_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'PERP_AGE_GROUP'],
    axis=1)
df = df.replace(to_replace='(null)', value=np.nan)
df.head()
# Out:
#    OCCUR_DATE OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0  05/05/2022   00:10:00  MANHATTAN            INSIDE        14
# 1  07/04/2022   22:20:00      BRONX           OUTSIDE        48
# 2  05/27/2012   19:35:00     QUEENS               NaN       103
# 3  09/24/2019   21:00:00      BRONX               NaN        42
# 4  02/25/2007   21:00:00   BROOKLYN               NaN        83
#
#   LOC_CLASSFCTN_DESC LOCATION_DESC  STATISTICAL_MURDER_FLAG VIC_AGE_GROUP  \
# 0         COMMERCIAL   VIDEO STORE                     True         25-44
# 1             STREET           NaN                     True         18-24
# 2                NaN           NaN                    False         18-24
# 3                NaN           NaN                    False         25-44
# 4                NaN           NaN                    False         25-44
#
#   VIC_SEX VIC_RACE   Latitude  Longitude
# 0       M    BLACK  40.754692 -73.993500
# 1       M    BLACK  40.854402 -73.882330
# 2       M    BLACK  40.710634 -73.767773
# 3       M    BLACK  40.832417 -73.890714
# 4       M    BLACK  40.688443 -73.910219

# %%
def get_month():
  months = []

  for date in df['OCCUR_DATE']:
    month_num = int(date.split("/")[0])
    months.append(calendar.month_name[month_num])

  return months

def time_ofday():

  def time_in_range(start, end, current):
    """Returns whether current is in the range [start, end]"""
    return start <= current <= end

  time = []
  time_dict = {
      "midnight": {
          "start": datetime.time(0, 0, 0),
          "end": datetime.time(3, 59, 59)
      },
      "early morning": {
          "start": datetime.time(4, 0, 0),
          "end": datetime.time(7, 59, 59)
      },
      "morning": {
          "start": datetime.time(8, 0, 0),
          "end": datetime.time(11, 59, 59)
      },
      "afternoon": {
          "start": datetime.time(12, 0, 0),
          "end": datetime.time(16, 59, 59)
      },
      "evening": {
          "start": datetime.time(17, 0, 0),
          "end": datetime.time(20, 59, 59)
      },
      "late evening": {
          "start": datetime.time(21, 0, 0),
          "end": datetime.time(23, 59, 59)
      }
  }

  for _, occur_time in enumerate(df['OCCUR_TIME']):
    for key, value in time_dict.items():
      if time_in_range(value.get("start"), value.get("end"), occur_time):
        time.append(key.title())

  return time

# %%
# convert occur_time to datetime object
df['OCCUR_TIME'] = pd.to_datetime(df['OCCUR_TIME'],format= '%H:%M:%S' ).dt.time
df['OCCUR_TIME'] = time_ofday()
df['OCCUR_DATE'] = get_month()

# %%
# victim age group modification
age_map = {
    '<18': '0-18',
    '18-24': '18-25',
    '25-44': '25-45',
    '45-64': '45-65',
    '65+': '65-100',
    'UNKNOWN': 'UNKNOWN'
}
df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].map(age_map)

# %%
df = df[df['VIC_AGE_GROUP'] != 'UNKNOWN']
df = df[df['VIC_RACE'] != 'UNKNOWN']
df = df[df['VIC_SEX'] != 'U']
df.head()
# Out:
#   OCCUR_DATE    OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0        May      Midnight  MANHATTAN            INSIDE        14
# 1       July  Late Evening      BRONX           OUTSIDE        48
# 2        May       Evening     QUEENS               NaN       103
# 3  September  Late Evening      BRONX               NaN        42
# 4   February  Late Evening   BROOKLYN               NaN        83
#
#   LOC_CLASSFCTN_DESC LOCATION_DESC  STATISTICAL_MURDER_FLAG VIC_AGE_GROUP  \
# 0         COMMERCIAL   VIDEO STORE                     True         25-45
# 1             STREET           NaN                     True         18-25
# 2                NaN           NaN                    False         18-25
# 3                NaN           NaN                    False         25-45
# 4                NaN           NaN                    False         25-45
#
#   VIC_SEX VIC_RACE   Latitude  Longitude
# 0       M    BLACK  40.754692 -73.993500
# 1       M    BLACK  40.854402 -73.882330
# 2       M    BLACK  40.710634 -73.767773
# 3       M    BLACK  40.832417 -73.890714
# 4       M    BLACK  40.688443 -73.910219

# %%
regions = df['BORO'].value_counts(sort=False).to_dict()
region_count = {
    'region': [ele for ele in list(regions.keys())],
    'count': [ele for ele in list(regions.values())]
}
region_df = pd.DataFrame(data=region_count)
region_df
# Out:
#           region  count
# 0      MANHATTAN   3752
# 1          BRONX   8341
# 2         QUEENS   4248
# 3       BROOKLYN  11298
# 4  STATEN ISLAND    804

# %%
area_count = px.bar(
    region_df, x='region', y='count',
    labels={'region': 'Region name', 'count': 'Number of victims'}
)
area_count.update_layout(
    title_text='Shooting incidents reported in each region of NYC',
    title_x=0.5
)
pyo.iplot(area_count, filename='Regionwise_Shooting_barplot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ae712ffd-6255-41ff-b922-dc2a9784808d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae712ffd-6255-41ff-b922-dc2a9784808d")) {                    Plotly.newPlot(                        "ae712ffd-6255-41ff-b922-dc2a9784808d",                        [{"alignmentgroup":"True","hovertemplate":"Region name=%{x}\u003cbr\u003eNumber of victims=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["MANHATTAN","BRONX","QUEENS","BROOKLYN","STATEN ISLAND"],"xaxis":"x","y":[3752,8341,4248,11298,804],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoord ...

# %%
area_pie = px.pie(
    data_frame=region_df,
    names = 'region',
    values = 'count'
)
area_pie.update_layout(
    title_text = 'Proportion of shooting cases reported in each region of NYC',
    title_x = 0.5
)
pyo.iplot(area_pie, filename='Regionwise_Shooting_pie')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="827c3c73-70e4-4cee-a03a-26ad2e3f978b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("827c3c73-70e4-4cee-a03a-26ad2e3f978b")) {                    Plotly.newPlot(                        "827c3c73-70e4-4cee-a03a-26ad2e3f978b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"region=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["MANHATTAN","BRONX","QUEENS","BROOKLYN","STATEN ISLAND"],"legendgroup":"","name":"","showlegend":true,"values":[3752,8341,4248,11298,804],"type":"pie"}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlin ...

# %% [markdown]
# # Monthly and daily analysis
#
# **Useful but unimplemented**: [Line plot as plt.graph_object](https://plotly.com/python/line-charts/)

# %%
month_to_num = {
    'January': 1, 'February': 2, 'March': 3,
    'April': 4, 'May': 5, 'June': 6, 'July': 7,
    'August': 8, 'September': 9, 'October': 10,
    'November': 11, 'December': 12
}

month_dict = df['OCCUR_DATE'].value_counts(sort=False).to_dict()
month_data = {'months': [ele for ele in list(month_dict.keys())],
              'count': [ele for ele in list(month_dict.values())]}
month_df = pd.DataFrame(month_data)
month_df['month_num'] = month_df['months'].map(month_to_num)
month_df = month_df.sort_values(by='month_num')
month_df = month_df.drop(labels=['month_num'], axis=1)
month_df
# Out:
#        months  count
# 10    January   1802
# 3    February   1441
# 11      March   1788
# 6       April   2063
# 0         May   2673
# 4        June   2948
# 1        July   3382
# 8      August   3249
# 2   September   2663
# 9     October   2366
# 7    November   2004
# 5    December   2064

# %%
monthly_plot = px.line(
    data_frame=month_df,
    x='months',
    y='count',
    markers=True,
    labels = {
        'months': 'Month of the year',
        'count': 'Number of victims'
    }
)
monthly_plot.update_layout(
    title_text='Monthly trend in reported shooting incidents over 10 years',
    title_x = 0.5,
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=True),
)
pyo.iplot(monthly_plot, filename='MonthlyTrend')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="79ab6ea0-aa37-46ba-b26c-7c5dda687dae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79ab6ea0-aa37-46ba-b26c-7c5dda687dae")) {                    Plotly.newPlot(                        "79ab6ea0-aa37-46ba-b26c-7c5dda687dae",                        [{"hovertemplate":"Month of the year=%{x}\u003cbr\u003eNumber of victims=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1802,1441,1788,2063,2673,2948,3382,3249,2663,2366,2004,2064],"yaxis":"y","type":"scatter"}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{" ...

# %%
time_to_num = {
    'Early Morning': 1, 'Morning': 2, 'Afternoon': 3,
    'Evening': 4, 'Late Evening': 5, 'Midnight': 6
}

time_dict = df['OCCUR_TIME'].value_counts(sort=False).to_dict()
time_data = {'time': [ele for ele in list(time_dict.keys())],
              'count': [ele for ele in list(time_dict.values())]}
time_df = pd.DataFrame(time_data)
time_df['time_num'] = time_df['time'].map(time_to_num)
time_df = time_df.sort_values(by='time_num')
time_df = time_df.drop(labels=['time_num'], axis=1)
time_df
# Out:
#             time  count
# 3  Early Morning   2853
# 5        Morning   1215
# 4      Afternoon   4014
# 2        Evening   5721
# 1   Late Evening   6716
# 0       Midnight   7924

# %%
time_plot = px.line(
    data_frame=time_df,
    x='time',
    y='count',
    markers=True,
    labels = {
        'time': 'Time of the day',
        'count': 'Number of victims'
    }
)
time_plot.update_layout(
    title_text='Daily trend in reported shooting incidents over 10 years',
    title_x = 0.5,
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=True),
)
pyo.iplot(time_plot, filename='DailyTrend')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52188ae1-268b-485c-8aa5-33eec49e7dee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52188ae1-268b-485c-8aa5-33eec49e7dee")) {                    Plotly.newPlot(                        "52188ae1-268b-485c-8aa5-33eec49e7dee",                        [{"hovertemplate":"Time of the day=%{x}\u003cbr\u003eNumber of victims=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["Early Morning","Morning","Afternoon","Evening","Late Evening","Midnight"],"xaxis":"x","y":[2853,1215,4014,5721,6716,7924],"yaxis":"y","type":"scatter"}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie": ...

# %% [markdown]
# # Age groups

# %%
age_to_num = {
    '0-18': 1, '18-25': 2, '25-45': 3,
    '45-65': 4, '65-100': 5
}
age_groups = df['VIC_AGE_GROUP'].value_counts(sort=False).to_dict()
age_data = {'age': [ele for ele in list(age_groups.keys())],
            'count': [ele for ele in list(age_groups.values())]}
age_df = pd.DataFrame(age_data)
age_df['age_num'] = age_df['age'].map(age_to_num)
age_df = age_df.sort_values(by='age_num')
age_df = age_df.drop(labels=['age_num'], axis=1)
age_df.head()
# Out:
#       age  count
# 4    0-18   2950
# 1   18-25  10360
# 0   25-45  12952
# 2   45-65   1975
# 3  65-100    205

# %%
age_radial = px.line_polar(
    age_df,
    r="count",
    theta="age",
    markers=True,
    line_close=True,
    start_angle=60
)
pyo.iplot(age_radial, filename='Radial')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9308c80f-7c29-483e-a1df-d3904b36326b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9308c80f-7c29-483e-a1df-d3904b36326b")) {                    Plotly.newPlot(                        "9308c80f-7c29-483e-a1df-d3904b36326b",                        [{"hovertemplate":"count=%{r}\u003cbr\u003eage=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","r":[2950,10360,12952,1975,205,2950],"showlegend":false,"subplot":"polar","theta":["0-18","18-25","25-45","45-65","65-100","0-18"],"type":"scatterpolar"}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"polar":{"angularaxis":{"direction":"clockwise","rotation":60},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# # Ethnicity Analysis

# %%
victim_race = df['VIC_RACE'].value_counts(sort=False).to_dict()
victim_race = {
    "race": [ele for ele in list(victim_race.keys())],
    "count": [ele for ele in list(victim_race.values())]
}
df_victim = pd.DataFrame(victim_race)
df_victim
# Out:
#                              race  count
# 0                           BLACK  20213
# 1                           WHITE    714
# 2                  WHITE HISPANIC   4275
# 3                  BLACK HISPANIC   2791
# 4        ASIAN / PACIFIC ISLANDER    439
# 5  AMERICAN INDIAN/ALASKAN NATIVE     11

# %%
annotation = [
    dict(
        xref='paper', yref='paper',
        x=0.5, y=0.5,
        xanchor= 'center',
        yanchor='middle',
        text= '<b>RACE OF VICTIMS</b>',
        font=dict(family="Arial", size=12),
        showarrow=False,
  )
]
ethnicity_pie = go.Figure(
    data = [
        go.Pie(
        labels=df_victim['race'].tolist(),
        values=df_victim['count'].tolist(),
        direction ='clockwise',
        hole=.8,
        sort=False
    )]
)
ethnicity_pie.update_layout(annotations=annotation)
pyo.iplot(ethnicity_pie, filename='Ethnicity_analysis_pie')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb6a5acf-4882-421f-a3cf-9223f1c8c7c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb6a5acf-4882-421f-a3cf-9223f1c8c7c0")) {                    Plotly.newPlot(                        "fb6a5acf-4882-421f-a3cf-9223f1c8c7c0",                        [{"direction":"clockwise","hole":0.8,"labels":["BLACK","WHITE","WHITE HISPANIC","BLACK HISPANIC","ASIAN \u002f PACIFIC ISLANDER","AMERICAN INDIAN\u002fALASKAN NATIVE"],"sort":false,"values":[20213,714,4275,2791,439,11],"type":"pie"}],                        {"annotations":[{"font":{"family":"Arial","size":12},"showarrow":false,"text":"\u003cb\u003eRACE OF VICTIMS\u003c\u002fb\u003e","x":0.5,"xanchor":"center","xref":"paper","y":0.5,"yanchor":"middle","yref":"paper"}],"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}] ...

# %% [markdown]
# # Locality of reported incidents

# %%
df_new = df.loc[:, ['BORO', 'LOC_CLASSFCTN_DESC']].dropna()
pivot = df_new.groupby(['BORO', 'LOC_CLASSFCTN_DESC']).size().unstack(fill_value=0)

# Reset index to convert the pivot table to a regular DataFrame
pivot_table = pivot.reset_index().drop(['STREET', 'OTHER', 'HOUSING'], axis=1)

# Melt the DataFrame to long format
df_locality = pivot_table.melt(id_vars='BORO', var_name='LOC_CLASSFCTN_DESC', value_name='Count')
# Print the melted DataFrame
df_locality
# Out:
#              BORO LOC_CLASSFCTN_DESC  Count
# 0           BRONX         COMMERCIAL     56
# 1        BROOKLYN         COMMERCIAL     75
# 2       MANHATTAN         COMMERCIAL     42
# 3          QUEENS         COMMERCIAL     31
# 4   STATEN ISLAND         COMMERCIAL      3
# 5           BRONX           DWELLING     65
# 6        BROOKLYN           DWELLING     99
# 7       MANHATTAN           DWELLING     18
# 8          QUEENS           DWELLING     46
# 9   STATEN ISLAND           DWELLING     14
# 10          BRONX        PARKING LOT      4
# 11       BROOKLYN        PARKING LOT      4
# 12      MANHATTAN        PARKING LOT      2
# 13         QUEENS        PARKING LOT      5
# 14  STATEN ISLAND        PARKING LOT      0
# 15          BRONX         PLAYGROUND      6
# 16       BROOKLYN         PLAYGROUND     12
# 17      MANHATTAN         PLAYGROUND     15
# 18         QUEENS         PLAYGROUND      7
# 19  STATEN ISLAND         PLAYGROUND      1
# 20          BRONX            TRANSIT      4
# 21       BROOKLYN            TRANSIT     12
# 22      MANHATTAN            TRANSIT      3
# 23         QUEENS            TRANSIT      4
# 24  STATEN ISLAND            TRANSIT      0
# 25          BRONX            VEHICLE      9
# 26       BROOKLYN            VEHICLE      7
# 27      MANHATTAN            VEHICLE      3
# 28         QUEENS            VEHICLE      9
# 29  STATEN ISLAND            VEHICLE      1

# %%
# Create the stacked bar plot
fig = px.bar(
    df_locality,
    x='BORO', y='Count',
    color='LOC_CLASSFCTN_DESC',
    labels={
        'BORO': 'Regions of NYC',
        'Count': 'Number of incidents reported'
    },
    barmode='stack'
)
fig.update_layout(
    title_text='Incidents reported in different localities in different regions',
    title_x=0.5,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        title="Locality classification",
        y=-0.2,
        xanchor="center",
        x=0.5,
        traceorder="grouped"
    ),
)
# Show the plot
pyo.iplot(fig, filename='Locality_classification_incident_count')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e724230-68cf-41c1-8ad7-01241af58fa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e724230-68cf-41c1-8ad7-01241af58fa5")) {                    Plotly.newPlot(                        "3e724230-68cf-41c1-8ad7-01241af58fa5",                        [{"alignmentgroup":"True","hovertemplate":"LOC_CLASSFCTN_DESC=COMMERCIAL\u003cbr\u003eRegions of NYC=%{x}\u003cbr\u003eNumber of incidents reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"COMMERCIAL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"COMMERCIAL","offsetgroup":"COMMERCIAL","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND"],"xaxis":"x","y":[56,75,42,31,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"LOC_CLASSFCTN_DESC=DWELLING\u003cbr\u003eRegions of NYC=%{x}\u003cbr\u003eNumber of incidents reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DWELLING","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"DWELLING","offsetgroup":"DWELLING","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND"],"xaxis":"x","y":[65,99,18,46,14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"LOC_CLASSFCTN_DESC=PARKING LOT\u003cbr\u003eRegions of NYC=%{x}\u003cbr\u003eNumber of incidents reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PARKING LOT","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"PARKING LOT","offsetgroup":"PARKING LOT","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND"],"xaxis":"x","y":[4,4,2,5,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"LOC_CLASSFCTN_DESC=PLAYGROUND\u003cbr\u003eRegions of NYC=%{x}\u003cbr\u003eNumber of incidents reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PLAYGROUND","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"PLAYGROUND","offsetgroup":"PLAYGROUND","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND"],"xaxis":"x","y":[6,12,15,7,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"LOC_CLASSFCTN_DESC=TRANSIT\u003cbr\u003eRegions of NYC=%{x}\u003cbr\u003eNumber of incidents reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TRANSIT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"TRANSIT","offsetgroup":"TRANSIT","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND"],"xaxis":"x","y":[4,12,3,4,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"LOC_CLASSFCTN_DESC=VEHICLE\u003cbr\u003eRegions of NYC=%{x}\u003cbr\u003eNumber of incidents reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"VEHICLE","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"VEHICLE","offsetgroup":"VEHICLE","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONX","BROOKLYN","MANHATTAN","QUEENS","STATEN ISLAND"],"xaxis":"x","y":[9,7,3,9,1],"yaxis":"y","type":"bar"}],                        {"barmode":"stack","legend":{"orientation":"h","title":{"text":"Locality classification"},"tracegroupgap":0,"traceorder":"grouped","x":0.5,"xanchor":"center","y":-0.2,"yanchor":"bottom"},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6" ...

# %% [markdown]
# # Age group of male and female victims

# %%
df_age = df.loc[:, ['VIC_AGE_GROUP', 'VIC_SEX']].dropna()
df_age = df_age.groupby(['VIC_AGE_GROUP', 'VIC_SEX']).size().unstack(fill_value=0)
pivot_table = df_age.reset_index()
df_age = pivot_table.melt(id_vars='VIC_AGE_GROUP', var_name='VIC_SEX', value_name='Count')
df_age
# Out:
#   VIC_AGE_GROUP VIC_SEX  Count
# 0          0-18       F    427
# 1         18-25       F    826
# 2         25-45       F   1072
# 3         45-65       F    366
# 4        65-100       F     63
# 5          0-18       M   2523
# 6         18-25       M   9534
# 7         25-45       M  11880
# 8         45-65       M   1609
# 9        65-100       M    142

# %%
# Create the stacked bar plot
fig = px.bar(
    df_age,
    x='VIC_AGE_GROUP', y='Count',
    color='VIC_SEX',
    labels={
        'VIC_AGE_GROUP': 'Age group of victims',
        'Count': 'Number of victims'
    },
    barmode='stack'
)
fig.update_layout(
    {
        "paper_bgcolor": "rgba(0, 0, 0, 0)",
        "plot_bgcolor": "rgba(0, 0, 0, 0)",
    },
    title_text='Gender wise representation of each age group',
    title_x=0.5,
)
# Show the plot
pyo.iplot(fig, filename='Age_Gender_count')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="77009c9a-8f42-4efe-9408-29727ff51a27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77009c9a-8f42-4efe-9408-29727ff51a27")) {                    Plotly.newPlot(                        "77009c9a-8f42-4efe-9408-29727ff51a27",                        [{"alignmentgroup":"True","hovertemplate":"VIC_SEX=F\u003cbr\u003eAge group of victims=%{x}\u003cbr\u003eNumber of victims=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["0-18","18-25","25-45","45-65","65-100"],"xaxis":"x","y":[427,826,1072,366,63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"VIC_SEX=M\u003cbr\u003eAge group of victims=%{x}\u003cbr\u003eNumber of victims=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["0-18","18-25","25-45","45-65","65-100"],"xaxis":"x","y":[2523,9534,11880,1609,142],"yaxis":"y","type":"bar"}],                        {"barmode":"stack","legend":{"title":{"text":"VIC_SEX"},"tracegroupgap":0},"margin":{"t":60},"paper_bgcolor":"rgba(0, 0, 0, 0)","plot_bgcolor":"rgba(0, 0, 0, 0)","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d088 ...

# %% [markdown]
# # Bonus plots
#
# Histogram of the PRECINCT column

# %%
hist = px.histogram(
    df, x='PRECINCT',
    labels={
        'PRECINCT': 'Numeric values of PRECINCT',
        'count': 'Frequency'
    }
)
hist.update_layout(
    title_text='Plot of PRECINCT column values',
    title_x=0.5
)
pyo.iplot(hist, filename='Histogram')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a4df6bc4-db44-4224-9711-f7914e6f2e28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4df6bc4-db44-4224-9711-f7914e6f2e28")) {                    Plotly.newPlot(                        "a4df6bc4-db44-4224-9711-f7914e6f2e28",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Numeric values of PRECINCT=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[14,48,103,42,83,23,113,77,48,49,73,114,114,28,43,71,106,105,7,41,113,73,47,46,32,83,48,108,49,100,110,75,113,42,67,49,71,73,44,84,88,67,47,75,46,47,113,103,79,79,23,108,50,94,71,75,42,71,49,40,75,75,71,50,40,45,44,43,101,70,60,113,46,101,105,67,42,52,101,63,32,44,105,81,46,69,75,60,83,101,52,40,79,104,40,73,34,46,49,75,73,106,46,49,49,42,32,44,20,75,70,75,71,46,115,48,75,48,103,44,81,121,73,61,9,71,114,23,75,61,43,107,120,69,120,79,105,73,121,105,45,113,101,73,120,71,73,79,100,75,32,32,120,83,75,40,83,110,47,67,81,41,68,50,23,81,42,71,67,43,44,48,32,106,47,42,73,28,63,113,48,108,73,75,61,75,40,66,75,52,70,71,24,106,1,40,70,120,113,81,81,73,45,46,81,69,25,106,25,23,81,30,42,46,32,83,63,32,23,63,75,113,67,114,32,75,120,120,62,48,73,104,69,32,103,71,42,61,73,114,75,110,47,70,73,42,110,75,47,47,67,88,44,67,33,47,42,67,103,32,50,25,44,42,105,101,45,40,43,25,67,73,105,48,67,48,48,114,30,26,88,48,69,115,75,83,90,47,52,42,24,120,71,67,81,43,43,69,76,23,67,70,42,67,73,40,75,81,113,47,46,73,52,41,18,104,73,23,26,33,77,40,14,52,67,32,81,44,63,61,63,42,113,113,101,106,60,123,101,88,101,60,46,48,33,79,49,73,34,103,73,32,75,25,113,67,70,46,103,61,73,48,67,42,66,67,120,79,120,60,79,47,49,75,79,77,44,113,23,70,70,60,73,79,73,73,79,60,7,73,30,9,60,75,10,67,75,32,83,46,34,42,44,46,75,60,44,90,103,90,25,43,73,46,73,73,120,75,52,44,69,75,75,40,120,60,47,43,101,63,71,42,120,33,83,48,46,32,24,71,105,49,48,40,120,67,25,73,77,79,48,105,42,104,73,70,73,19,67,73,33,77,77,67,41,41,102,48,73,101,120,48,75,113,32,60,70,43,43,73,48,41,47,67,26,47,110,77,71,63,47,61,81,103,43,83,75,47,50,114,79,79,43,44,83,83,20,70,69,44,79,83,70,81,48,46,43,83,83,105,90,101,48,43,77,113,73,34,60,81,43,25,76,73,52,73,48,66,79,103,48,75,81,47,32,77,63,10,45,41,75,75,42,25,52,25,48,48,69,47,24,110,83,25,9,47,42,42,113,43,42,121,77,44,43,40,73,34,103,42,73,75,63,73,73,67,73,84,47,42,69,77,73,81,33,113,52,24,40,79,47,75,41,44,67,48,75,40,101,103,7,32,43,81,63,103,40,23,46,73,47,44,79,71,67,28,75,101,49,90,46,32,105,67,79,46,83,40,49,67,70,47,52,66,30,28,106,44,77,70,45,33,44,75,75,60,73,48,103,47,113,48,75,52,69,28,41,48,46,60,48,101,73,75,44,88,94,106,104,42,32,71,76,90,67,47,61,25,78,103,61,75,71,67,106,43,67,40,114,50,73,81,52,49,73,120,41,42,90,81,40,105,105,67,113,67,45,81,48,40,46,46,40,90,105,100,77,73,81,43,69,71,101,46,34,103,46,73,14,67,34,101,60,47,73,90,94,52,69,75,70,105,101,67,23,75,47,69,48,49,47,88,47,70,122,70,75,67,46,49,44,75,48,52,75,79,45,32,79,61,75,34,113,75,43,46,42,79,76,103,30,40,34,46,81,50,103,47,121,49,6,32,69,23,79,79,7,84,79,42,46,73,67,50,41,88,75,34,40,101,44,77,75,110,83,46,44,115,23,67,79,75,83,48,43,69,75,47,75,120,70,75,83,49,69,46,115,60,46,46,83,47,114,60,88,47,62,40,67,79,114,61,81,70,28,81,120,77,106,40,104,32,44,113,73,75,73,49,47,120,105,105,70,46,40,7,67,123,81,40,43,47,42,113,81,63,61,114,77,46,44,75,63,25,121,105,28,81,71,43,113,70,67,24,47,46,42,41,44,44,120,108,60,100,73,60,44,30,94,77,103,71,23,83,113,109,75,81,46,28,83,77,106,42,83,113,77,69,100,42,94,101,70,101,102,94,45,47,42,46,113,77,47,75,67,42,75,70,105,71,79,81,25,63,67,40,61,63,67,67,44,73,73,43,40,70,48,114,47,25,122,77,26,10,43,4 ...

# %% [markdown]
# Sankey diagram for classification and description
#
# [Reference](https://stackoverflow.com/a/72764554)

# %%
hierarchy = df[['LOC_CLASSFCTN_DESC', 'LOCATION_DESC']].dropna()
hierarchy = hierarchy[hierarchy['LOC_CLASSFCTN_DESC']!='OTHER']
hierarchy.loc[hierarchy.LOCATION_DESC.str.contains("STORE"),'LOCATION_DESC'] = "STORE"
hierarchy.loc[hierarchy.LOCATION_DESC.str.contains("HOUS"),'LOCATION_DESC'] = "HOUSE"
hierarchy.loc[hierarchy.LOCATION_DESC.str.contains("CLUB"),'LOCATION_DESC'] = "CLUB"
hierarchy = hierarchy.groupby(['LOC_CLASSFCTN_DESC', 'LOCATION_DESC']).size().unstack(fill_value=0)
pivot_table = hierarchy.reset_index()
loc_df = pivot_table.melt(id_vars='LOC_CLASSFCTN_DESC', var_name='LOCATION_DESC', value_name='Count')
loc_df = loc_df[loc_df['Count']!=0]
loc_df
# Out:
#    LOC_CLASSFCTN_DESC            LOCATION_DESC  Count
# 0          COMMERCIAL        BEAUTY/NAIL SALON      6
# 4              STREET        BEAUTY/NAIL SALON      8
# 5          COMMERCIAL                     CLUB     40
# 9              STREET                     CLUB     45
# 10         COMMERCIAL          COMMERCIAL BLDG      6
# 13        PARKING LOT          COMMERCIAL BLDG      7
# 14             STREET          COMMERCIAL BLDG     26
# 15         COMMERCIAL      DRY CLEANER/LAUNDRY      1
# 20         COMMERCIAL                FAST FOOD      1
# 23        PARKING LOT                FAST FOOD      1
# 24             STREET                FAST FOOD     29
# 25         COMMERCIAL              GAS STATION      3
# 29             STREET              GAS STATION      9
# 30         COMMERCIAL           GROCERY/BODEGA     67
# 34             STREET           GROCERY/BODEGA     60
# 35         COMMERCIAL                 HOSPITAL      3
# 39             STREET                 HOSPITAL      4
# 40         COMMERCIAL              HOTEL/MOTEL      1
# 41           DWELLING              HOTEL/MOTEL      1
# 45         COMMERCIAL                    HOUSE      2
# 46           DWELLING                    HOUSE     47
# 47            HOUSING                    HOUSE    448
# 49             STREET                    HOUSE     43
# 50         COMMERCIAL  MULTI DWELL - APT BUILD      2
# 51           DWELLING  MULTI DWELL - APT BUILD    172
# 52            HOUSING  MULTI DWELL - APT BUILD      6
# 54             STREET  MULTI DWELL - APT BUILD    110
# 55         COMMERCIAL         RESTAURANT/DINER     12
# 59             STREET         RESTAURANT/DINER      6
# 60         COMMERCIAL           SMALL MERCHANT     17
# 64             STREET           SMALL MERCHANT      2
# 65         COMMERCIAL                    STORE     18
# 69             STREET                    STORE     11
# 74             STREET              SUPERMARKET      2

# %%
classifications = list(set(loc_df['LOC_CLASSFCTN_DESC'].tolist()))
descriptions = list(set(loc_df['LOCATION_DESC'].tolist()))
classification_dict = {}
description_dict = {}
classification_idx = 0

for idx, classification in enumerate(classifications):
  classification_dict.update({classification: idx})
  classification_idx = idx

for idx, description in enumerate(descriptions):
  description_dict.update({description: classification_idx+1+idx})

print(classification_dict)
print(description_dict)
# Out:
# {'DWELLING': 0, 'STREET': 1, 'COMMERCIAL': 2, 'PARKING LOT': 3, 'HOUSING': 4}
# {'SMALL MERCHANT': 5, 'FAST FOOD': 6, 'GAS STATION': 7, 'COMMERCIAL BLDG': 8, 'HOTEL/MOTEL': 9, 'SUPERMARKET': 10, 'CLUB': 11, 'GROCERY/BODEGA': 12, 'DRY CLEANER/LAUNDRY': 13, 'HOUSE': 14, 'BEAUTY/NAIL SALON': 15, 'MULTI DWELL - APT BUILD': 16, 'RESTAURANT/DINER': 17, 'STORE': 18, 'HOSPITAL': 19}

# %%
# add source and target columns to dataframe
def get_source_target(df):
  source_list, target_list = [], []
  for row in df['LOC_CLASSFCTN_DESC']:
    source_list.append(classification_dict.get(row))

  for row in df['LOCATION_DESC']:
    target_list.append(description_dict.get(row))

  return source_list, target_list

# %%
loc_df['Source'], loc_df['Target'] = get_source_target(df=loc_df)
loc_df = loc_df.drop_duplicates()
loc_df
# Out:
#    LOC_CLASSFCTN_DESC            LOCATION_DESC  Count  Source  Target
# 0          COMMERCIAL        BEAUTY/NAIL SALON      6       2      15
# 4              STREET        BEAUTY/NAIL SALON      8       1      15
# 5          COMMERCIAL                     CLUB     40       2      11
# 9              STREET                     CLUB     45       1      11
# 10         COMMERCIAL          COMMERCIAL BLDG      6       2       8
# 13        PARKING LOT          COMMERCIAL BLDG      7       3       8
# 14             STREET          COMMERCIAL BLDG     26       1       8
# 15         COMMERCIAL      DRY CLEANER/LAUNDRY      1       2      13
# 20         COMMERCIAL                FAST FOOD      1       2       6
# 23        PARKING LOT                FAST FOOD      1       3       6
# 24             STREET                FAST FOOD     29       1       6
# 25         COMMERCIAL              GAS STATION      3       2       7
# 29             STREET              GAS STATION      9       1       7
# 30         COMMERCIAL           GROCERY/BODEGA     67       2      12
# 34             STREET           GROCERY/BODEGA     60       1      12
# 35         COMMERCIAL                 HOSPITAL      3       2      19
# 39             STREET                 HOSPITAL      4       1      19
# 40         COMMERCIAL              HOTEL/MOTEL      1       2       9
# 41           DWELLING              HOTEL/MOTEL      1       0       9
# 45         COMMERCIAL                    HOUSE      2       2      14
# 46           DWELLING                    HOUSE     47       0      14
# 47            HOUSING                    HOUSE    448       4      14
# 49             STREET                    HOUSE     43       1      14
# 50         COMMERCIAL  MULTI DWELL - APT BUILD      2       2      16
# 51           DWELLING  MULTI DWELL - APT BUILD    172       0      16
# 52            HOUSING  MULTI DWELL - APT BUILD      6       4      16
# 54             STREET  MULTI DWELL - APT BUILD    110       1      16
# 55         COMMERCIAL         RESTAURANT/DINER     12       2      17
# 59             STREET         RESTAURANT/DINER      6       1      17
# 60         COMMERCIAL           SMALL MERCHANT     17       2       5
# 64             STREET           SMALL MERCHANT      2       1       5
# 65         COMMERCIAL                    STORE     18       2      18
# 69             STREET                    STORE     11       1      18
# 74             STREET              SUPERMARKET      2       1      10

# %%
sankey_node = dict(
    label = classifications+descriptions,
    line = dict(color = "black", width = 0.5),
    pad = 15,
    thickness = 20,
    x = [0.001, 0.001, 0.001, 0.001, 0.001],
    y = [0.001, 75/285, 160/285, 190/285, 0.001, 75/285, 130/285, 215/285],
    color = ["#305CA3", "#C9304E", "#C1DAF1", "#F7DC70", "#5CA330"]
)

sankey_link = dict(
    source = loc_df['Source'],
    target = loc_df['Target'],
    value = loc_df['Count'],
)

sankey = go.Figure(data=[go.Sankey(
    arrangement='snap',
    node = sankey_node,
    link = sankey_link
    )
])
sankey.update_layout(
    title_text="Location Categories and Descriptions as a Sankey Diagram",
    title_x=0.5,
    font_size=10
)
pyo.iplot(sankey, filename='Sankey')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a9203dec-a7ca-4ec4-865f-b27a89a177fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9203dec-a7ca-4ec4-865f-b27a89a177fb")) {                    Plotly.newPlot(                        "a9203dec-a7ca-4ec4-865f-b27a89a177fb",                        [{"arrangement":"snap","link":{"source":[2,1,2,1,2,3,1,2,2,3,1,2,1,2,1,2,1,2,0,2,0,4,1,2,0,4,1,2,1,2,1,2,1,1],"target":[15,15,11,11,8,8,8,13,6,6,6,7,7,12,12,19,19,9,9,14,14,14,14,16,16,16,16,17,17,5,5,18,18,10],"value":[6,8,40,45,6,7,26,1,1,1,29,3,9,67,60,3,4,1,1,2,47,448,43,2,172,6,110,12,6,17,2,18,11,2]},"node":{"color":["#305CA3","#C9304E","#C1DAF1","#F7DC70","#5CA330"],"label":["DWELLING","STREET","COMMERCIAL","PARKING LOT","HOUSING","SMALL MERCHANT","FAST FOOD","GAS STATION","COMMERCIAL BLDG","HOTEL\u002fMOTEL","SUPERMARKET","CLUB","GROCERY\u002fBODEGA","DRY CLEANER\u002fLAUNDRY","HOUSE","BEAUTY\u002fNAIL SALON","MULTI DWELL - APT BUILD","RESTAURANT\u002fDINER","STORE","HOSPITAL"],"line":{"color":"black","width":0.5},"pad":15,"thickness":20,"x":[0.001,0.001,0.001,0.001,0.001],"y":[0.001,0.2631578947368421,0.5614035087719298,0.6666666666666666,0.001,0.2631578947368421,0.45614035087719296,0.7543859649122807]},"type":"sankey"}],                        {"font":{"size":10},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333 ...

# %% [markdown]
# # Plotting on a map
#
# 1. [Guide using GeoPandas](https://plotly.com/python/scattermapbox/)
# 2. [All kind of maps](https://plotly.com/python/maps/)

# %%
px.set_mapbox_access_token(token="pk.eyJ1IjoiZGl2aS0wMDciLCJhIjoiY2x3dnRlMnU4MG5vOTJycXprMG1pOGZ3dCJ9.WULsINqBNsYBvpo11qP7kg")

# %%
murder_df = df[df['STATISTICAL_MURDER_FLAG']][['BORO', 'Latitude', 'Longitude']].dropna()
murder_df
# Out:
#             BORO   Latitude  Longitude
# 0      MANHATTAN  40.754692 -73.993500
# 1          BRONX  40.854402 -73.882330
# 6         QUEENS  40.673306 -73.789887
# 9          BRONX  40.860463 -73.865561
# 11        QUEENS  40.769744 -73.909872
# ...          ...        ...        ...
# 28544   BROOKLYN  40.634916 -73.932963
# 28549     QUEENS  40.700826 -73.881490
# 28551   BROOKLYN  40.695772 -73.979528
# 28557      BRONX  40.903785 -73.850098
# 28559      BRONX  40.821404 -73.898938
#
# [5500 rows x 3 columns]

# %%
shooting_map = px.scatter_mapbox(
    murder_df, lat="Latitude", lon="Longitude", color='BORO',
    color_continuous_scale=px.colors.cyclical.IceFire, size_max=2, zoom=10
)
shooting_map.update_layout(
    title_text="Map depicting shooting incidents in NYC",
    title_x=0.5,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.1,
        xanchor="center",
        x=0.5,
        traceorder="grouped",
        title="REGION",
        bgcolor="yellow"
    )
)
pyo.iplot(shooting_map, filename='Map')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="622f5a5b-7f4a-4fc7-99f7-4cb619028c5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("622f5a5b-7f4a-4fc7-99f7-4cb619028c5f")) {                    Plotly.newPlot(                        "622f5a5b-7f4a-4fc7-99f7-4cb619028c5f",                        [{"hovertemplate":"BORO=MANHATTAN\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[40.754692,40.86092831600007,40.77320620200004,40.727598,40.79621443500002,40.82134496100008,40.78673086700008,40.785419570000045,40.81472912700008,40.84569911700004,40.798285,40.72760591300005,40.743462,40.7206733,40.79605805500006,40.71366629200002,40.80770036400003,40.802539833000026,40.8009303727402,40.754692,40.864136643000045,40.861107,40.71754737100008,40.82171487700003,40.796789371000045,40.86475888300004,40.829860403000055,40.83433552500002,40.814267648000055,40.72649141400007,40.710781936000046,40.73902192000002,40.788526,40.794604263000046,40.80037966700007,40.864136643000045,40.81471283000008,40.81279641500004,40.807137586000074,40.70998316000004,40.807323446000055,40.79409419700005,40.82867408600004,40.754692,40.80536404400005,40.82811591600006,40.82690592200004,40.71313820000006,40.80022069900008,40.8009303727402,40.82988338300004,40.816041573000064,40.81662638500006,40.80195370100006,40.79819366700008,40.829956,40.82194166900007,40.80707512000004,40.847706351000056,40.78926022400003,40.72081286900004,40.78926022400003,40.80128284700004,40.78926022400003,40.81593041000008,40.72399576700008,40.815057,40.829286,40.79898644700006,40.834069554000045,40.79945482100004,40.81304510900002,40.85170536100002,40.800880121000034,40.796341580000046,40.72081286900004,40.839987396000026,40.8009303727402,40.80747207100006,40.79605805500006,40.816057570000055,40.749576,40.78872008500008,40.70998316000004,40.847706351000056,40.83899952100006,40.84903644400004,40.82716143000005,40.86446884900005,40.80760896700008,40.79009424900005,40.73280557600003,40.82622541300003,40.852046201000064,40.800880121000034,40.82514751300005,40.75286289900004,40.83489727200004,40.79898644700006,40.83282665100006,40.81052438000006,40.82835177000004,40.75217469500007,40.78998178500007,40.79958152300003,40.80977891300006,40.82988338300004,40.806635,40.862256614000046,40.79792604000005,40.82590884200005,40.86391521900004,40.80038551600006,40.83990820100007,40.78833555700004,40.757316640000056,40.822935777000055,40.80941341300007,40.80308081300007,40.79829200900008,40.804221601000044,40.79397898800005,40.82871989100005,40.726817,40.81052438000006,40.72081286900004,40.80067124200008,40.81600399600006,40.83433552500002,40.80138710500006,40.78872008500008,40.80209197100004,40.81667027000003,40.749576,40.80024342500008,40.754692,40.867482393000046,40.74772704300005,40.70998316000004,40.78998178500007,40.84620036200005,40.79814694600003,40.711932756000074,40.85915335400006,40.81092011900006,40.774059273000034,40.80149420600002,40.78606022200006,40.72943481300007,40.839987396000026,40.81270971400005,40.80059328900006,40.79800141000004,40.74772704300005,40.73812676400007,40.78811954200007,40.742237338000045,40.81476310800008,40.820974294000045,40.7426636084461,40.806634604000074,40.77388246500004,40.867458818000046,40.84812006,40.82065353500008,40.808558408000074,40.78872008500008,40.816041573000064,40.796382,40.80661720900008,40.79387380300005,40.79967505400003,40.763784,40.711382,40.86446884900005,40.79850134400005,40.81593041000008,40.81659705000004,40.82037051000003,40.795659,40.70561926600004,40.79946680100005,40.809045383000075,40.72081286900004,40.81374703900008,40.78551835000008,40.80661720900008,40.75286289900004,40.815057,40.808445263000074,40.789323,40.79513027700 ...
